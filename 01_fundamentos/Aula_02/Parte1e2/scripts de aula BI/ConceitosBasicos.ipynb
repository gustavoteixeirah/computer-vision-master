# %% [markdown]
# #Conceitos Básicos

# %% [markdown]
# ##Comentários e Variáveis

# %%
# teste
a = 1
a
# Out:
# 1

# %%
preco_carro = 200000

# %%
preco_carro
# Out:
# 200000

# %%
print(preco_carro)
# Out:
# 200000

# %%
preco_carro_2 = 100_000

# %%
# Só imprime o último
preco_carro
preco_carro_2
# Out:
# 100000

# %%
# para imprimir todos precisa de print (numa única célula)
print(preco_carro)
print(preco_carro_2)
# Out:
# 200000
# 100000

# %%
print(preco_carro, preco_carro_2)
# Out:
# 200000 100000

# %%
# sep é o separdor dos objetos passados para uma mesma função print
print(preco_carro, preco_carro_2, sep='---------')
# Out:
# 200000---------100000

# %%
1e5
# Out:
# 100000.0

# %% [markdown]
# ##Tipo Numérico

# %%
# Tipo Inteiro (int)
a = 4
type(a)
# Out:
# int

# %%
# Tipo Real (float)
b = 5.0
type(b)
# Out:
# float

# %% [markdown]
# ##Tipo Booleano

# %%
q1 = True
type(q1)
# Out:
# bool

# %%
q2 = False
type(q2)
# Out:
# bool

# %%
# Internamente True = 1, False = 0
q1 + q2
# Out:
# 1

# %%
q1 + q1
# Out:
# 2

# %%
# Operações com variáveis booleanas
q1 and q2
# Out:
# False

# %%
q1 or q2
# Out:
# True

# %% [markdown]
# ## Tipo Sequência

# %%
# Strings
nome = 'Manoela'
curso = "BI Master"

# %%
type(nome)
# Out:
# str

# %%
# Acessar o primeiro elemento dentro de uma sequência
# OBS: em python, indexação começa em zero!!!
# Primeiro elemento é o elemento de índice 0.
nome[0]
# Out:
# 'M'

# %%
# Segundo elemento
nome[1]
# Out:
# 'a'

# %%
# Último elemento
nome[-1]
# Out:
# 'a'

# %%
# len retorna o número de elementos de uma sequência
nome[len(nome) - 1]
# Out:
# 'a'

# %%
# Função split para splitar strings
nome_completo = "Manoela Kohler"
nome_separado = nome_completo.split(' ')
nome_separado[1] + ", " + nome_separado[0][0]  # + para string é concatenação
# Out:
# 'Kohler, M'

# %%
# primeiros elementos. [i:f] => i inclusive, f exclusive
nome[0:3]
# Out:
# 'Man'

# %%
nome[0] + nome[3]  # + para string é concatenação
# Out:
# 'Mo'

# %%
# Lista
lista1 = []  # crio uma lista vazia
type(lista1)
# Out:
# list

# %%
lista1 = list()  # crio uma lista vazia
type(lista1)
# Out:
# list

# %%
lista1 = ['PUC-Rio', 'BI Master', 2024, 1, 534.5, True, [1, 2, 3, 4]]
lista1
# Out:
# ['PUC-Rio', 'BI Master', 2024, 1, 534.5, True, [1, 2, 3, 4]]

# %%
# Acessar primeiro elemento
lista1[0]
# Out:
# 'PUC-Rio'

# %%
# último elemento
lista1[-1]
# Out:
# [1, 2, 3, 4]

# %%
# segundo elemento dentro do último elemento
lista1[-1][1]
# Out:
# 2

# %%
# append add um elemento ao final da lista
lista1.append('python')
lista1
# Out:
# ['PUC-Rio', 'BI Master', 2024, 1, 534.5, True, [1, 2, 3, 4], 'python']

# %%
lista1[-1]
# Out:
# 'python'

# %%
# Retorna o número de ocorrências do valor passado por parâmetro
lista1.count(1)  # 1 retorna 2 pois temos o 1 int e o True (1)
# Out:
# 2

# %%
# Retirada de espaços
nome_completo.replace(" ", "")
# Out:
# 'ManoelaKohler'

# %%
# trimming do início e fim da string
teste = "  fhds  dfhasf  fjdsia    "
teste.strip()
# Out:
# 'fhds  dfhasf  fjdsia'

# %%
# Se sua busca for por padrões e condições mais complexas
# regex : expressão regular

# %%
lista1[-2].count(1)
# Out:
# 1

# %%
# Remover primeira ocorerência de um valor
lista1.remove(1)
lista1
# Out:
# ['PUC-Rio', 'BI Master', 2024, 534.5, True, [1, 2, 3, 4], 'python']

# %%
# Remove elemento de índice 1 da lista: segundo elemento
lista1.pop(1)
# Out:
# 'BI Master'

# %%
lista1
# Out:
# ['PUC-Rio', 2024, 534.5, True, [1, 2, 3, 4], 'python']

# %%
# Tuplas
tupla1 = tuple()
type(tupla1)
# Out:
# tuple

# %%
tupla1 = ()
type(tupla1)
# Out:
# tuple

# %%
tupla1 = ("PUC-Rio", 'cce', 2024, '2024.1')
tupla1
# Out:
# ('PUC-Rio', 'cce', 2024, '2024.1')

# %%
# primeiro elemento
tupla1[0]
# Out:
# 'PUC-Rio'

# %%
# Retorna o número de ocorrência do valor passado
tupla1.count('cce')
# Out:
# 1

# %%
# Retorna o índice do valor passado
tupla1.index(2024)
# Out:
# 2

# %%
tupla1[2] + 3
# Out:
# 2027

# %%
float(tupla1[3]) + 3
# Out:
# 2027.1

# %%
tupla1[3] + str(3)
# Out:
# '2024.13'

# %%
# Não pode modificar a tupla, ela é imutável, mas sobrescrevê-la pode!
tupla1 = "teste"
type(tupla1)
# Out:
# str

# %%
type(tupla1[3])
# Out:
# str

# %%
lista1
# Out:
# ['PUC-Rio', 2024, 534.5, True, [1, 2, 3, 4], 'python']

# %%
lista1[0] = 'puc'
lista1
# Out:
# ['puc', 2024, 534.5, True, [1, 2, 3, 4], 'python']

# %%
tupla1 = ("PUC-Rio", 'cce', 2024, '2024.1')

# %%
tupla1
# Out:
# ('PUC-Rio', 'cce', 2024, '2024.1')

# %%
tupla1 = ("PUC-Rio", 'cce', 2024, '2024.1', 'aaa')

# %%
tupla1
# Out:
# ('PUC-Rio', 'cce', 2024, '2024.1', 'aaa')

# %%
tupla1 = (*tupla1, 4, 5)
tupla1
# Out:
# ('PUC-Rio', 'cce', 2024, '2024.1', 'aaa', 4, 5)

# %% [markdown]
# ## Conjuntos (Set)

# %%
conjunto = set()
type(conjunto)
# Out:
# set

# %%
conjunto = set(['puc', 'rio', 2024, 1, 'python', 2024, 1])
conjunto
# Out:
# {1, 2024, 'puc', 'python', 'rio'}

# %%
conjunto.add(2)
conjunto
# Out:
# {1, 2, 2024, 'puc', 'python', 'rio'}

# %%
conjunto2 = set([1,2, 'bi', 'cce', 64365])
conjunto2
# Out:
# {1, 2, 64365, 'bi', 'cce'}

# %%
conjunto.intersection(conjunto2)
# Out:
# {1, 2}

# %%
conjunto.union(conjunto2)
# Out:
# {1, 2, 2024, 64365, 'bi', 'cce', 'puc', 'python', 'rio'}

# %%
conjunto.difference(conjunto2)
# Out:
# {2024, 'puc', 'python', 'rio'}

# %% [markdown]
# ##Dicionários

# %%
dicionario = {}
type(dicionario)
# Out:
# dict

# %%
dicionario = dict()
type(dicionario)
# Out:
# dict

# %%
# {chave:valor, chave2:valor2}
dicionario = {'Universidade':'Puc-Rio', 'Turma':2024.1, 'Curso':'BiMaster'}
dicionario
# Out:
# {'Universidade': 'Puc-Rio', 'Turma': 2024.1, 'Curso': 'BiMaster'}

# %%
# Buscar valor a partir da chave
dicionario['Universidade']
# Out:
# 'Puc-Rio'

# %%
dicionario = {'Universidade':['Puc-Rio', 'PUC-SP'], 'Turma':2024.1, 'Curso':'BiMaster'}

# %%
# Buscar valor a partir da chave
dicionario['Universidade']
# Out:
# ['Puc-Rio', 'PUC-SP']

# %%
# Adicionar novo par chave:valor ao dicionário
dicionario['Aluno'] = 'Felipe'

# %%
dicionario
# Out:
# {'Universidade': ['Puc-Rio', 'PUC-SP'],
#  'Turma': 2024.1,
#  'Curso': 'BiMaster',
#  'Aluno': 'Felipe'}

# %%
# Modificar valor de uma chave existente
dicionario['Aluno'] = 'Diogo'
dicionario
# Out:
# {'Universidade': ['Puc-Rio', 'PUC-SP'],
#  'Turma': 2024.1,
#  'Curso': 'BiMaster',
#  'Aluno': 'Diogo'}

# %%
dicionario.keys()
# Out:
# dict_keys(['Universidade', 'Turma', 'Curso', 'Aluno'])

# %%
dicionario.pop('Curso')
# Out:
# 'BiMaster'

# %%
dicionario
# Out:
# {'Universidade': ['Puc-Rio', 'PUC-SP'], 'Turma': 2024.1, 'Aluno': 'Diogo'}

# %% [markdown]
# #Operações

# %%
a = 5
b = 10

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# -5

# %%
# a elevado a 2
a**2
# Out:
# 25

# %%
import math
math.pow(a, 2)
# Out:
# 25.0

# %%
# raiz quadrada de a
a**(1/2)
# Out:
# 2.23606797749979

# %%
math.sqrt(a)
# Out:
# 2.23606797749979

# %%
# comparação de igualdade

a == b
# Out:
# False

# %%
# comparação de desigualdade
a != b
# Out:
# True

# %%
# Menor ou igual
a <= b
# Out:
# True

# %%
a > b
# Out:
# False

# %% [markdown]
# # Exercícios

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
var1 = 6
type(var1)
# Out:
# int

# %%
var2 = 2
type(var2)
# Out:
# int

# %%
var3 = var1 / var2
var3
# Out:
# 3.0

# %%
type(var3)
# Out:
# float

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lucro_mensal = 8_000
lucro_total = lucro_mensal * 12
lucro_total
# Out:
# 96000

# %%
amigo1 = lucro_total * 0.3
print('O lucro do amigo1 é de R$', "{:.2f}".format(amigo1), sep='')
# Out:
# O lucro do amigo1 é de R$28800.00

# %%
amigo2 = lucro_total - amigo1
print('O lucro do amigo2 é de R$', "{:.2f}".format(amigo2), sep='')
# Out:
# O lucro do amigo2 é de R$67200.00

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
5 + 3 * 10 / 3 == 15
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1.
movieName = "The Shining"
actors=["Jack Nicholson", "Shelley Duvall", "Danny Lloyd", "Scatman Crothers", "Barry Nelson"]
scores=[4.5,4.0,5.0]
comments=["Best Horror Film I Have Ever Seen", "A truly brilliant and scary film from Stanley Kubrick", "A masterpiece of psychological horror"]

# %%
lista = [movieName, actors, scores, comments]
lista
# Out:
# ['The Shining',
#  ['Jack Nicholson',
#   'Shelley Duvall',
#   'Danny Lloyd',
#   'Scatman Crothers',
#   'Barry Nelson'],
#  [4.5, 4.0, 5.0],
#  ['Best Horror Film I Have Ever Seen',
#   'A truly brilliant and scary film from Stanley Kubrick',
#   'A masterpiece of psychological horror']]

# %%
# Primeiro ator
lista[1][0]
# Out:
# 'Jack Nicholson'

# %%
# melhor avaliação (score e comentário)
avaliacoes = lista[2]
maior_score = max(avaliacoes)
maior_score
# Out:
# 5.0

# %%
comentarios = lista[-1]
comentarios
# Out:
# ['Best Horror Film I Have Ever Seen',
#  'A truly brilliant and scary film from Stanley Kubrick',
#  'A masterpiece of psychological horror']

# %%
idx = avaliacoes.index(maior_score)
idx
# Out:
# 2

# %%
comentarios[idx]
# Out:
# 'A masterpiece of psychological horror'

# %% [markdown]
# #Type Casting

# %%
texto = "O preço é R$"
valor = 2000

# %%
documento = texto + str(valor)
documento
# Out:
# 'O preço é R$2000'

# %%
documento.split('R$')
# Out:
# ['O preço é ', '2000']

# %%
valor_str = documento.split('R$')[1]
valor_str
# Out:
# '2000'

# %%
aumento = 0.05
float(valor_str) * aumento
# Out:
# 100.0

# %% [markdown]
# # Interação com usuário

# %%
idade = input('Qual a sua idade?')
# Out:
# Qual a sua idade?37

# %%
idade
# Out:
# '37'

# %%
import datetime
ano_corrente = datetime.datetime.now().year
ano_corrente
# Out:
# 2024

# %%
ano_corrente - int(idade)
# Out:
# 1987
